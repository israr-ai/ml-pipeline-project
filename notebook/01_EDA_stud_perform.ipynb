# %% [markdown]
# ### Student Performance Indicator
#
# LIfe cycle of Machine learning Project
#
#   . Understanding the problem Statement
#   . Data Collection
#   . Data checks to perforom
#   . Exploratory data analysis
#   . Data Pre-Processing
#   . Model Training
#   . Choose best Model

# %% [markdown]
# ### 1) Probelm Statement
#
#  . This project understands how the student's performance (test score) is affected by other variable such  as Gender, Ethnicity Parental level of education, Lunch and Test preparation course.

# %% [markdown]
# ### 2) Data Collection
#
#
# .Dataset source - https://www.kaggle.com/datasets/sharif33/student-dataset-csv
#
# .The data consists of 8 column and 1000 rows.

# %% [markdown]
# ### 2.1) Import Data and Required Packages
#
#
# Importing Pandas , Numpy, Matplotlib, Seaborn and Warings library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\shaikh\AppData\Local\Programs\Python\Python311\python.exe

# %% [markdown]
# ### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv('data/stud_data_new.csv')
# df2 = pd.read_csv('data/Student_Performance.csv')
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  ...  \
# 0                   84.3             yes     <15 min              yes  ...
# 1                   87.8             yes     >60 min               no  ...
# 2                   65.5              no     <15 min               no  ...
# 3                   58.1              no   15-30 min               no  ...
# 4                   61.0             yes   30-60 min              yes  ...
#
#   science_score  english_score  overall_score  final_grade race_ethnicity  \
# 0          55.4           57.0           53.1            e        group B
# 1          68.8           64.8           61.3            d        group C
# 2          95.0           79.2           89.6            b        group B
# 3          27.5           54.7           41.6            e        group A
# 4          32.7           30.0           25.4            f        group C
#
#           lunch test_preparation_course math_score  reading_score  \
# 0      standard                    none         72             72
# 1      standard               completed         69             90
# 2      standard                    none         90             95
# 3  free/reduced                    none         47             57
# 4      standard                    none         76             78
#
#    writing_score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Show Top 5 REcords

# %%
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  ...  \
# 0                   84.3             yes     <15 min              yes  ...
# 1                   87.8             yes     >60 min               no  ...
# 2                   65.5              no     <15 min               no  ...
# 3                   58.1              no   15-30 min               no  ...
# 4                   61.0             yes   30-60 min              yes  ...
#
#   science_score  english_score  overall_score  final_grade race_ethnicity  \
# 0          55.4           57.0           53.1            e        group B
# 1          68.8           64.8           61.3            d        group C
# 2          95.0           79.2           89.6            b        group B
# 3          27.5           54.7           41.6            e        group A
# 4          32.7           30.0           25.4            f        group C
#
#           lunch test_preparation_course math_score  reading_score  \
# 0      standard                    none         72             72
# 1      standard               completed         69             90
# 2      standard                    none         90             95
# 3  free/reduced                    none         47             57
# 4      standard                    none         76             78
#
#    writing_score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (1000, 21)

# %% [markdown]
# ### 2.2 Dataset Information
#
#  .gender :sex of students -> (Male/female)
#  .race/ethnicity: ethinicity of students-> (Group A, B, C, D,E)
#  . parental level of education: parents' final education ->(bachelor's degree, some college, master's, degree, associate's degree, high school)
#  .lunch : having lunch before test (standard or free/reduuced)
#  .test preparation course: complete or not complete before test
#  .math score
#  .reading score
#  .writing score

# %% [markdown]
# #### 3. Data Checks to perform
#
#   . Check Missing values
#   . Check Duplicates
#   . Check data type
#   . Check the number of unique values of each column
#   . Check statistics of the data set
#   . Check various categories present in the different categorical column

# %% [markdown]
# #### 3.1 Check Missing values

# %%
df.isna().sum()
# Out:
# student_id                 0
# age                        0
# gender                     0
# school_type                0
# parent_education           0
# study_hours                0
# attendance_percentage      0
# internet_access            0
# travel_time                0
# extra_activities           0
# study_method               0
# science_score              0
# english_score              0
# overall_score              0
# final_grade                0
# race_ethnicity             0
# lunch                      0
# test_preparation_course    0
# math_score                 0
# reading_score              0
# writing_score              0
# dtype: int64

# %% [markdown]
# There are no missing values in the data set

# %% [markdown]
# #### 3.2 Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates values in the data set

# %% [markdown]
# ### 3.3 Check data type

# %%
# check null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               1000 non-null   int64
#  1   age                      1000 non-null   int64
#  2   gender                   1000 non-null   object
#  3   school_type              1000 non-null   object
#  4   parent_education         1000 non-null   object
#  5   study_hours              1000 non-null   float64
#  6   attendance_percentage    1000 non-null   float64
#  7   internet_access          1000 non-null   object
#  8   travel_time              1000 non-null   object
#  9   extra_activities         1000 non-null   object
#  10  study_method             1000 non-null   object
#  11  science_score            1000 non-null   float64
#  12  english_score            1000 non-null   float64
#  13  overall_score            1000 non-null   float64
#  14  final_grade              1000 non-null   object
#  15  race_ethnicity           1000 non-null   object
#  16  lunch                    1000 non-null   object
#  17  test_preparation_course  1000 non-null   object
#  18  math_score               1000 non-null   int64
#  19  reading_score            1000 non-null   int64
#  20  writing_score            1000 non-null   int64
# dtypes: float64(5), int64(5), object(11)
# memory usage: 164.2+ KB

# %% [markdown]
# ### 3.4 Checking the  number of unique values of each column

# %%
df.nunique()
# Out:
# student_id                 1000
# age                           6
# gender                        3
# school_type                   2
# parent_education              6
# study_hours                  76
# attendance_percentage       432
# internet_access               2
# travel_time                   4
# extra_activities              2
# study_method                  6
# science_score               526
# english_score               559
# overall_score               528
# final_grade                   6
# race_ethnicity                5
# lunch                         2
# test_preparation_course       2
# math_score                   81
# reading_score                72
# writing_score                77
# dtype: int64

# %% [markdown]
# ### 3.5 Check statistics of data set

# %%
df.describe()
# Out:
#         student_id          age  study_hours  attendance_percentage  \
# count  1000.000000  1000.000000  1000.000000            1000.000000
# mean    500.500000    16.488000     4.289700              75.013900
# std     288.819436     1.719539     2.148828              14.030957
# min       1.000000    14.000000     0.500000              50.000000
# 25%     250.750000    15.000000     2.400000              63.000000
# 50%     500.500000    17.000000     4.300000              75.100000
# 75%     750.250000    18.000000     6.100000              86.850000
# max    1000.000000    19.000000     8.000000             100.000000
#
#        science_score  english_score  overall_score  math_score  reading_score  \
# count    1000.000000    1000.000000    1000.000000  1000.00000    1000.000000
# mean       63.890300      63.768300      64.227500    66.08900      69.169000
# std        20.359876      20.797132      18.447523    15.16308      14.600192
# min         0.000000       1.000000      21.600000     0.00000      17.000000
# 25%        49.200000      48.300000      50.075000    57.00000      59.000000
# 50%        63.550000      64.050000      63.850000    66.00000      70.000000
# 75%        79.150000      79.400000      79.025000    77.00000      79.000000
# max       100.000000     100.000000     100.000000   100.00000     100.000000
#
#        writing_score
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000

# %% [markdown]
# ##### insight
#
#   . From above description of numerical data , all means are very close to each other - between 66 and 68.05;
#   . All standard deviations are also close - between 14.6 and 15.19;
#   .while there is a minimum score 0 for math, for writing minimum is much higher = 10 and for reading mynet higher = 17

# %% [markdown]
# #### 3.7 Exploring Data

# %%
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  ...  \
# 0                   84.3             yes     <15 min              yes  ...
# 1                   87.8             yes     >60 min               no  ...
# 2                   65.5              no     <15 min               no  ...
# 3                   58.1              no   15-30 min               no  ...
# 4                   61.0             yes   30-60 min              yes  ...
#
#   science_score  english_score  overall_score  final_grade race_ethnicity  \
# 0          55.4           57.0           53.1            e        group B
# 1          68.8           64.8           61.3            d        group C
# 2          95.0           79.2           89.6            b        group B
# 3          27.5           54.7           41.6            e        group A
# 4          32.7           30.0           25.4            f        group C
#
#           lunch test_preparation_course math_score  reading_score  \
# 0      standard                    none         72             72
# 1      standard               completed         69             90
# 2      standard                    none         90             95
# 3  free/reduced                    none         47             57
# 4      standard                    none         76             78
#
#    writing_score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75
#
# [5 rows x 21 columns]

# %%
print("Categories in 'gender' variable:    ",end="")
print(df['gender'].unique())

print("Categories in 'race_ethnicity' variable:  ",end=" ")
print(df['race_ethnicity'].unique())

print("Categories in 'parental_education' variable: ",end=" ")
print(df['parent_education'].unique())

print("Categories in 'lunch' variable: ", end=" ")
print(df['lunch'].unique())

print("Categories in 'test_preparation_course' variable: ", end=" ")
print(df['test_preparation_course'].unique())
# Out:
# Categories in 'gender' variable:    ['male' 'female' 'other']
# Categories in 'race_ethnicity' variable:   ['group B' 'group C' 'group A' 'group D' 'group E']
# Categories in 'parental_education' variable:  ['post graduate' 'graduate' 'high school' 'no formal' 'diploma' 'phd']
# Categories in 'lunch' variable:  ['standard' 'free/reduced']
# Categories in 'test_preparation_course' variable:  ['none' 'completed']

# %%
# numerical columns
numeric_features = df.select_dtypes(include=['number']).columns

# categorical columns
categorical_features = df.select_dtypes(include=['object', 'category']).columns

print(f"We have {len(numeric_features)} numerical features: {list(numeric_features)}")
print(f"\nWe have {len(categorical_features)} categorical features: {list(categorical_features)}")
# Out:
# We have 10 numerical features: ['student_id', 'age', 'study_hours', 'attendance_percentage', 'science_score', 'english_score', 'overall_score', 'math_score', 'reading_score', 'writing_score']
#
# We have 11 categorical features: ['gender', 'school_type', 'parent_education', 'internet_access', 'travel_time', 'extra_activities', 'study_method', 'final_grade', 'race_ethnicity', 'lunch', 'test_preparation_course']

# %% [markdown]
# #### Adding columns for "Total Score" and "Average"

# %%
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  ...  \
# 0                   84.3             yes     <15 min              yes  ...
# 1                   87.8             yes     >60 min               no  ...
# 2                   65.5              no     <15 min               no  ...
# 3                   58.1              no   15-30 min               no  ...
# 4                   61.0             yes   30-60 min              yes  ...
#
#   science_score  english_score  overall_score  final_grade race_ethnicity  \
# 0          55.4           57.0           53.1            e        group B
# 1          68.8           64.8           61.3            d        group C
# 2          95.0           79.2           89.6            b        group B
# 3          27.5           54.7           41.6            e        group A
# 4          32.7           30.0           25.4            f        group C
#
#           lunch test_preparation_course math_score  reading_score  \
# 0      standard                    none         72             72
# 1      standard               completed         69             90
# 2      standard                    none         90             95
# 3  free/reduced                    none         47             57
# 4      standard                    none         76             78
#
#    writing_score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75
#
# [5 rows x 21 columns]

# %%
df['total_score'] = df['math_score'] + df['science_score'] + df['english_score']
df['average'] = df['total_score']/3
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  ...  \
# 0                   84.3             yes     <15 min              yes  ...
# 1                   87.8             yes     >60 min               no  ...
# 2                   65.5              no     <15 min               no  ...
# 3                   58.1              no   15-30 min               no  ...
# 4                   61.0             yes   30-60 min              yes  ...
#
#   overall_score  final_grade  race_ethnicity         lunch  \
# 0          53.1            e         group B      standard
# 1          61.3            d         group C      standard
# 2          89.6            b         group B      standard
# 3          41.6            e         group A  free/reduced
# 4          25.4            f         group C      standard
#
#   test_preparation_course math_score reading_score writing_score  total_score  \
# 0                    none         72            72            74        184.4
# 1               completed         69            90            88        202.6
# 2                    none         90            95            93        264.2
# 3                    none         47            57            44        129.2
# 4                    none         76            78            75        138.7
#
#      average
# 0  61.466667
# 1  67.533333
# 2  88.066667
# 3  43.066667
# 4  46.233333
#
# [5 rows x 23 columns]

# %%
math_full = df[df['math_score'] == 100]['average'].count()
science_full = df[df['science_score'] == 100]['average'].count()
english_full = df[df['english_score'] == 100]['average'].count()

print(f'Number of student with full marks in Maths:{math_full}')
print(f'Number of Students with full marks in science:{science_full}')
print(f'Number of students with full marks in English:{english_full}')
# Out:
# Number of student with full marks in Maths:7
# Number of Students with full marks in science:42
# Number of students with full marks in English:41

# %%
science_less_20 = df[df['science_score'] <= 20]['average'].count()
english_less_20 = df[df['english_score'] <= 20]['average'].count()
math_less_20 = df[df['math_score'] <= 20]['average'].count()

print(f'Number of student with less than 20 marks in Maths: {math_less_20}')
print(f'Number of student with less than 20 marks in English : {english_less_20}')
print(f'Number of student with less than 20 marks in Science : {science_less_20}')
# Out:
# Number of student with less than 20 marks in Maths: 4
# Number of student with less than 20 marks in English : 15
# Number of student with less than 20 marks in Science : 14

# %% [markdown]
# #### Inights
#
#   . From above values we get students have performed the worst in Maths
#   . Best performance is in rading section.

# %% [markdown]
# #### 4. Exploring Data (Visualization)
#
# ##### 4.1 Visualize average  score distribution to make some conclusion.
#
#   .Histogram
#   . Kernel Distribution Function(KDE)

# %% [markdown]
# #### 4.1.1 Histogram & KDE

# %%
fig, axs = plt.subplots(1,2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data =df, x='total_score', bins=30, kde=True, color='g')
plt.subplot(122)
sns.histplot(data =  df, x='total_score', kde = True, hue ='gender')
plt.show()

# %% [markdown]
# #### Inights
#
#    . Female students tend to perform well then male sttudents.

# %%
plt.subplots(1, 3, figsize=(25, 6))
plt.subplot(141)
sns.histplot(data = df, x='average', kde=True, hue='lunch')
plt.subplot(142) 
sns.histplot(data = df[df.gender =='female'], x='average', kde=True, hue='lunch')
plt.subplot(143)
sns.histplot(data= df[df.gender == 'male'], x='average', kde=True, hue='lunch')
plt.show()

# %%
import pandas as pd

df = pd.read_csv("data/stud_data_new.csv")

print(df.shape)
print(df.isnull().sum())
# Out:
# (1000, 21)
# student_id                 0
# age                        0
# gender                     0
# school_type                0
# parent_education           0
# study_hours                0
# attendance_percentage      0
# internet_access            0
# travel_time                0
# extra_activities           0
# study_method               0
# science_score              0
# english_score              0
# overall_score              0
# final_grade                0
# race_ethnicity             0
# lunch                      0
# test_preparation_course    0
# math_score                 0
# reading_score              0
# writing_score              0
# dtype: int64
